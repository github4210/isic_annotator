# %%
import os
import json

decision_tree = '../static/rev3/decisiontree-backup.json'
decision_tree_out = '../static/rev3/decisiontree.json'
dtree = json.load(open(decision_tree, 'r'))

# %%
struct_list = []
c_offset = 0


def parseTree(step, parent, iconpath, color):
    global c_offset
    
    if 'value' in step.keys():
        
        step['longtitle'] = parent + step['title']
        c_offset 
        
        import copy
        
        new_c = copy.copy(color)

        for i,c in enumerate(color):
            if c == 0:
                new_c[i] = c_offset
        
        c_offset += 1
        

                
        res = [ step['value'], parent + step['title'], iconpath + '.jpg', new_c]

        struct_list.append(res)
    
    if len(step['options']) > 0:
        for n, opt in enumerate(step['options']):
            parseTree(opt, parent + step['title'] + ': ', iconpath + '/' + str(n+1), color)

# http://colorschemedesigner.com/            
color_list = [[251, 0, 13],
              [236, 252, 0],
              [126, 0, 169],
              [20, 209, 0],
              [0, 140, 255]]


for n,o in enumerate(dtree[4]['options']):
    c_offset = 0
    parseTree(o, '', 'static/rev3/4' + '/' + str(n+1), color_list[n])

# %%
struct_list
# Out:
# [[10, u'Lines', 'static/rev3/1.jpg', [251, 0, 13]],
#  [20, u'Lines: Reticular', 'static/rev3/1/1.jpg', [251, 1, 13]],
#  [21, u'Lines: Reticular: Regular', 'static/rev3/1/1/1.jpg', [251, 2, 13]],
#  [22, u'Lines: Reticular: Thick', 'static/rev3/1/1/2.jpg', [251, 3, 13]],
#  [23, u'Lines: Reticular: Thin', 'static/rev3/1/1/3.jpg', [251, 4, 13]],
#  [24, u'Lines: Reticular: Atypical', 'static/rev3/1/1/4.jpg', [251, 5, 13]],
#  [25,
#   u'Lines: Reticular: Negative Network',
#   'static/rev3/1/1/5.jpg',
#   [251, 6, 13]],
#  [30, u'Lines: Radial', 'static/rev3/1/2.jpg', [251, 7, 13]],
#  [31,
#   u'Lines: Radial: Radial lines connected to a common base',
#   'static/rev3/1/2/1.jpg',
#   [251, 8, 13]],
#  [32,
#   u'Lines: Radial: Radial lines converging to a central dot',
#   'static/rev3/1/2/2.jpg',
#   [251, 9, 13]],
#  [33,
#   u'Lines: Radial: Radial lines, peripheral',
#   'static/rev3/1/2/3.jpg',
#   [251, 10, 13]],
#  [40, u'Lines: Branched', 'static/rev3/1/3.jpg', [251, 11, 13]],
#  [50, u'Lines: Parallel and straight', 'static/rev3/1/4.jpg', [251, 12, 13]],
#  [51,
#   u'Lines: Parallel and straight: Furrows',
#   'static/rev3/1/4/1.jpg',
#   [251, 13, 13]],
#  [52,
#   u'Lines: Parallel and straight: Ridges',
#   'static/rev3/1/4/2.jpg',
#   [251, 14, 13]],
#  [53,
#   u'Lines: Parallel and straight: Fibrallar',
#   'static/rev3/1/4/3.jpg',
#   [251, 15, 13]],
#  [60, u'Lines: Curved', 'static/rev3/1/5.jpg', [251, 16, 13]],
#  [61, u'Lines: Curved: Thick', 'static/rev3/1/5/1.jpg', [251, 17, 13]],
#  [62, u'Lines: Curved: Thin', 'static/rev3/1/5/2.jpg', [251, 18, 13]],
#  [70, u'Dots & Clods', 'static/rev3/2.jpg', [236, 252, 0]],
#  [71, u'Dots & Clods: Dots', 'static/rev3/2/1.jpg', [236, 252, 1]],
#  [72,
#   u'Dots & Clods: Dots: Atypical Dots',
#   'static/rev3/2/1/1.jpg',
#   [236, 252, 2]],
#  [73,
#   u'Dots & Clods: Dots: Dots, Four square',
#   'static/rev3/2/1/2.jpg',
#   [236, 252, 3]],
#  [74,
#   u'Dots & Clods: Dots: Dots, Circle',
#   'static/rev3/2/1/3.jpg',
#   [236, 252, 4]],
#  [75,
#   u'Dots & Clods: Dots: Dots, Lines',
#   'static/rev3/2/1/4.jpg',
#   [236, 252, 5]],
#  [76, u'Dots & Clods: Clods', 'static/rev3/2/2.jpg', [236, 252, 6]],
#  [77,
#   u'Dots & Clods: Clods: Atypical Clods',
#   'static/rev3/2/2/1.jpg',
#   [236, 252, 7]],
#  [80, u'Structureless', 'static/rev3/3.jpg', [126, 0, 169]],
#  [81, u'Structureless: Blue-White Veil', 'static/rev3/3/1.jpg', [126, 1, 169]],
#  [82, u'Structureless: Pseudonetwork', 'static/rev3/3/2.jpg', [126, 2, 169]],
#  [83,
#   u'Structureless: Peripheral brown structureless area',
#   'static/rev3/3/3.jpg',
#   [126, 3, 169]],
#  [100, u'Vessels', 'static/rev3/4.jpg', [20, 209, 0]],
#  [110, u'Vessels: Lines', 'static/rev3/4/1.jpg', [20, 209, 1]],
#  [111, u'Vessels: Lines: Straight', 'static/rev3/4/1/1.jpg', [20, 209, 2]],
#  [112, u'Vessels: Lines: Looped', 'static/rev3/4/1/2.jpg', [20, 209, 3]],
#  [113,
#   u'Vessels: Lines: Looped: Looped with white Halo',
#   'static/rev3/4/1/2/1.jpg',
#   [20, 209, 4]],
#  [114, u'Vessels: Lines: Curved', 'static/rev3/4/1/3.jpg', [20, 209, 5]],
#  [115, u'Vessels: Lines: Serpentine', 'static/rev3/4/1/4.jpg', [20, 209, 6]],
#  [116, u'Vessels: Lines: Helical', 'static/rev3/4/1/5.jpg', [20, 209, 7]],
#  [117, u'Vessels: Lines: Coiled', 'static/rev3/4/1/6.jpg', [20, 209, 8]],
#  [118, u'Vessels: Lines: Branched', 'static/rev3/4/1/7.jpg', [20, 209, 9]],
#  [101, u'Vessels: Dots', 'static/rev3/4/2.jpg', [20, 209, 10]],
#  [102, u'Vessels: Clods', 'static/rev3/4/3.jpg', [20, 209, 11]],
#  [120, u'Vessels: Milky-red area', 'static/rev3/4/4.jpg', [20, 209, 12]],
#  [130, u'Vessels: Polymorphous vessels', 'static/rev3/4/5.jpg', [20, 209, 13]],
#  [140, u'Other', 'static/rev3/5.jpg', [0, 140, 255]],
#  [150, u'Other: Shiny white lines', 'static/rev3/5/1.jpg', [1, 140, 255]],
#  [151, u'Other: Circles', 'static/rev3/5/2.jpg', [2, 140, 255]],
#  [152, u'Other: Pseudopods', 'static/rev3/5/3.jpg', [3, 140, 255]],
#  [153,
#   u'Other: Sharply demarcated scalloped border',
#   'static/rev3/5/4.jpg',
#   [4, 140, 255]]]

# %%
for s in struct_list:
#                             { name: '21', color: [21, 255, 255]},

    print '''{ name: '%s', color: %s, icon: "%s", title: '%s' },''' % (s[0], s[3], s[2], s[1])
# Out:
# { name: '10', color: [251, 0, 13], icon: "static/rev3/1.jpg", title: 'Lines' },
# { name: '20', color: [251, 1, 13], icon: "static/rev3/1/1.jpg", title: 'Lines: Reticular' },
# { name: '21', color: [251, 2, 13], icon: "static/rev3/1/1/1.jpg", title: 'Lines: Reticular: Regular' },
# { name: '22', color: [251, 3, 13], icon: "static/rev3/1/1/2.jpg", title: 'Lines: Reticular: Thick' },
# { name: '23', color: [251, 4, 13], icon: "static/rev3/1/1/3.jpg", title: 'Lines: Reticular: Thin' },
# { name: '24', color: [251, 5, 13], icon: "static/rev3/1/1/4.jpg", title: 'Lines: Reticular: Atypical' },
# { name: '25', color: [251, 6, 13], icon: "static/rev3/1/1/5.jpg", title: 'Lines: Reticular: Negative Network' },
# { name: '30', color: [251, 7, 13], icon: "static/rev3/1/2.jpg", title: 'Lines: Radial' },
# { name: '31', color: [251, 8, 13], icon: "static/rev3/1/2/1.jpg", title: 'Lines: Radial: Radial lines connected to a common base' },
# { name: '32', color: [251, 9, 13], icon: "static/rev3/1/2/2.jpg", title: 'Lines: Radial: Radial lines converging to a central dot' },
# { name: '33', color: [251, 10, 13], icon: "static/rev3/1/2/3.jpg", title: 'Lines: Radial: Radial lines, peripheral' },
# { name: '40', color: [251, 11, 13], icon: "static/rev3/1/3.jpg", title: 'Lines: Branched' },
# { name: '50', color: [251, 12, 13], icon: "static/rev3/1/4.jpg", title: 'Lines: Parallel and straight' },
# { name: '51', color: [251, 13, 13], icon: "static/rev3/1/4/1.jpg", title: 'Lines: Parallel and straight: Furrows' },
# { name: '52', color: [251, 14, 13], icon: "static/rev3/1/4/2.jpg", title: 'Lines: Parallel and straight: Ridges' },
# { name: '53', color: [251, 15, 13], icon: "static/rev3/1/4/3.jpg", title: 'Lines: Parallel and straight: Fibrallar' },
# { name: '60', color: [251, 16, 13], icon: "static/rev3/1/5.jpg", title: 'Lines: Curved' },
# { name: '61', color: [251, 17, 13], icon: "static/rev3/1/5/1.jpg", title: 'Lines: Curved: Thick' },
# { name: '62', color: [251, 18, 13], icon: "static/rev3/1/5/2.jpg", title: 'Lines: Curved: Thin' },
# { name: '70', color: [236, 252, 0], icon: "static/rev3/2.jpg", title: 'Dots & Clods' },
# { name: '71', color: [236, 252, 1], icon: "static/rev3/2/1.jpg", title: 'Dots & Clods: Dots' },
# { name: '72', color: [236, 252, 2], icon: "static/rev3/2/1/1.jpg", title: 'Dots & Clods: Dots: Atypical Dots' },
# { name: '73', color: [236, 252, 3], icon: "static/rev3/2/1/2.jpg", title: 'Dots & Clods: Dots: Dots, Four square' },
# { name: '74', color: [236, 252, 4], icon: "static/rev3/2/1/3.jpg", title: 'Dots & Clods: Dots: Dots, Circle' },
# { name: '75', color: [236, 252, 5], icon: "static/rev3/2/1/4.jpg", title: 'Dots & Clods: Dots: Dots, Lines' },
# { name: '76', color: [236, 252, 6], icon: "static/rev3/2/2.jpg", title: 'Dots & Clods: Clods' },
# { name: '77', color: [236, 252, 7], icon: "static/rev3/2/2/1.jpg", title: 'Dots & Clods: Clods: Atypical Clods' },
# { name: '80', color: [126, 0, 169], icon: "static/rev3/3.jpg", title: 'Structureless' },
# { name: '81', color: [126, 1, 169], icon: "static/rev3/3/1.jpg", title: 'Structureless: Blue-White Veil' },
# { name: '82', color: [126, 2, 169], icon: "static/rev3/3/2.jpg", title: 'Structureless: Pseudonetwork' },
# { name: '83', color: [126, 3, 169], icon: "static/rev3/3/3.jpg", title: 'Structureless: Peripheral brown structureless area' },
# { name: '100', color: [20, 209, 0], icon: "static/rev3/4.jpg", title: 'Vessels' },
# { name: '110', color: [20, 209, 1], icon: "static/rev3/4/1.jpg", title: 'Vessels: Lines' },
# { name: '111', color: [20, 209, 2], icon: "static/rev3/4/1/1.jpg", title: 'Vessels: Lines: Straight' },
# { name: '112', color: [20, 209, 3], icon: "static/rev3/4/1/2.jpg", title: 'Vessels: Lines: Looped' },
# { name: '113', color: [20, 209, 4], icon: "static/rev3/4/1/2/1.jpg", title: 'Vessels: Lines: Looped: Looped with white Halo' },
# { name: '114', color: [20, 209, 5], icon: "static/rev3/4/1/3.jpg", title: 'Vessels: Lines: Curved' },
# { name: '115', color: [20, 209, 6], icon: "static/rev3/4/1/4.jpg", title: 'Vessels: Lines: Serpentine' },
# { name: '116', color: [20, 209, 7], icon: "static/rev3/4/1/5.jpg", title: 'Vessels: Lines: Helical' },
# { name: '117', color: [20, 209, 8], icon: "static/rev3/4/1/6.jpg", title: 'Vessels: Lines: Coiled' },
# { name: '118', color: [20, 209, 9], icon: "static/rev3/4/1/7.jpg", title: 'Vessels: Lines: Branched' },
# { name: '101', color: [20, 209, 10], icon: "static/rev3/4/2.jpg", title: 'Vessels: Dots' },
# { name: '102', color: [20, 209, 11], icon: "static/rev3/4/3.jpg", title: 'Vessels: Clods' },
# { name: '120', color: [20, 209, 12], icon: "static/rev3/4/4.jpg", title: 'Vessels: Milky-red area' },
# { name: '130', color: [20, 209, 13], icon: "static/rev3/4/5.jpg", title: 'Vessels: Polymorphous vessels' },
# { name: '140', color: [0, 140, 255], icon: "static/rev3/5.jpg", title: 'Other' },
# { name: '150', color: [1, 140, 255], icon: "static/rev3/5/1.jpg", title: 'Other: Shiny white lines' },
# { name: '151', color: [2, 140, 255], icon: "static/rev3/5/2.jpg", title: 'Other: Circles' },
# { name: '152', color: [3, 140, 255], icon: "static/rev3/5/3.jpg", title: 'Other: Pseudopods' },
# { name: '153', color: [4, 140, 255], icon: "static/rev3/5/4.jpg", title: 'Other: Sharply demarcated scalloped border' },

# %%
import json

json.dump(dtree, open(decision_tree_out, 'w'))
