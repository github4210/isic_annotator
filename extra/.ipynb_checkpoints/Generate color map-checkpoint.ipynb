# %%
# singular generation process

# %%
import os
import json
import copy

decision_tree = '../static/rev3/decisiontree-backup.json'
decision_tree_out = '../static/rev3/decisiontree.json'
dtree = json.load(open(decision_tree, 'r'))

struct_list = []
c_offset = 0


def imageToFilename(imname):
    final_name = imname.replace(' ', '').replace(':', '_').replace('&', '-').replace(',', '-').lower()
    return final_name

def parseTree(step, parent, iconpath, color = [0,0,0]):
    
    global c_offset
    
    if 'drop' in step['type']:    
        step['longtitle'] = parent + step['title']
        c_offset 
        new_c = copy.copy(color)
        
        # create new color for this entry
        for i,c in enumerate(color):
            if c == 0:
                new_c[i] = c_offset
        c_offset += 1

        value = ''     
        if 'value' in step.keys():
           value = step['value'] 
        
        realimg = imageToFilename(parent + step['title'])
        step['icon'] = 'static/derm/images/' +  realimg + '.jpg'
        res = [int(iconpath.split('/')[0]), value, parent + step['title'],step['title'], iconpath, new_c, realimg, step['type']]        
        struct_list.append(res)
    
    if 'drop' in step['type'] or 'select' in step['type']:
        if len(step['options']) > 0:
            for n, opt in enumerate(step['options']):
                if '/' in iconpath:
                    parseTree(opt, parent + step['title'] + ': ', iconpath + '/' + str(n+1), color)
                else:
                    base_color = color_list[n]
                    parseTree(opt, '', iconpath + '/' + str(n+1), base_color)                

# http://colorschemedesigner.com/            
color_list = [[251, 0, 13],
              [236, 252, 0],
              [126, 0, 169],
              [20, 209, 0],
              [0, 140, 255]]

for n,o in enumerate(dtree):
    if 'select' in o['type']:
        parseTree(o, '', str(n))

# %%
# step, value, full name containing parent, short name, nested path, color, new icon name, and type

struct_list[-1]
# Out:
# [5,
#  153,
#  u'Other: Sharply demarcated scalloped border',
#  u'Sharply demarcated scalloped border',
#  '5/5/4',
#  [60, 140, 255],
#  u'other_sharplydemarcatedscallopedborder',
#  u'selectdrop']

# %%
# now let's convert the images!

import os, glob, sys, shutil

# %%
image_path = '../static/rev2/'
outdir = '../static/derm/images/'

if not os.path.exists(outdir):
    os.makedirs(outdir)

for s in struct_list:
    
    infile = glob.glob(image_path + s[4] + '*.*')
    outfile = outdir + s[6] + '.jpg'
#     print target_img
    
    cmdstr = '/usr/local/bin/convert ./%s  -gravity center -resize 300x200 -extent 300x200 -background white ./%s' % (infile, outfile)
    print cmdstr
#     pipe = os.popen(cmdstr)
#     for p in pipe:
#         print p
# Out:
# /usr/local/bin/convert ./['../static/rev2/3/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines-reticular.jpg
# /usr/local/bin/convert ./['../static/rev2/3/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines-parallel.jpg
# /usr/local/bin/convert ./['../static/rev2/3/2/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines-parallel_furrow.jpg
# /usr/local/bin/convert ./['../static/rev2/3/2/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines-parallel_ridge.jpg
# /usr/local/bin/convert ./['../static/rev2/3/2/3.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines-parallel_fibrillar.jpg
# /usr/local/bin/convert ./['../static/rev2/3/3.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/clods.jpg
# /usr/local/bin/convert ./['../static/rev2/3/3/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/clods_cobblestoneclods.jpg
# /usr/local/bin/convert ./['../static/rev2/3/3/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/clods_regular(round/oval)clods.jpg
# /usr/local/bin/convert ./['../static/rev2/3/4.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/homogeneous.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/1.png']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_reticular.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/1/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_reticular_regular.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/1/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_reticular_thick.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/1/3.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_reticular_thin.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/1/4.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_reticular_atypical.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/1/5.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_reticular_negativenetwork.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/2.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_radial.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/2/1.png']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_radial_radiallinesconnectedtoacommonbase.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/2/2.png']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_radial_radiallinesconvergingtoacentraldot.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/2/3.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_radial_radiallines-peripheral.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/3.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_branched.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/4.png']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_parallelandstraight.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/4/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_parallelandstraight_furrows.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/4/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_parallelandstraight_ridges.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/4/3.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_parallelandstraight_fibrallar.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/5.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_curved.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/5/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_curved_thick.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/5/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_curved_thin.jpg
# /usr/local/bin/convert ./['../static/rev2/5/1/6.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/lines_zigzag.jpg
# /usr/local/bin/convert ./['../static/rev2/5/2.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/dots-clods.jpg
# /usr/local/bin/convert ./['../static/rev2/5/2/1.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/dots-clods_dots.jpg
# /usr/local/bin/convert ./['../static/rev2/5/2/1/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/dots-clods_dots_atypicaldots.jpg
# /usr/local/bin/convert ./['../static/rev2/5/2/1/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/dots-clods_dots_dots-foursquare.jpg
# /usr/local/bin/convert ./['../static/rev2/5/2/1/3.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/dots-clods_dots_dots-circle.jpg
# /usr/local/bin/convert ./['../static/rev2/5/2/1/4.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/dots-clods_dots_dots-lines.jpg
# /usr/local/bin/convert ./['../static/rev2/5/2/2.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/dots-clods_clods.jpg
# /usr/local/bin/convert ./['../static/rev2/5/2/2/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/dots-clods_clods_atypicalclods.jpg
# /usr/local/bin/convert ./['../static/rev2/5/3.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/structureless.jpg
# /usr/local/bin/convert ./['../static/rev2/5/3/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/structureless_blue-whiteveil.jpg
# /usr/local/bin/convert ./['../static/rev2/5/3/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/structureless_pseudonetwork.jpg
# /usr/local/bin/convert ./['../static/rev2/5/3/3.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/structureless_peripheralbrownstructurelessarea.jpg
# /usr/local/bin/convert ./['../static/rev2/5/3/4.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/structureless_off-centeredblotch.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4.png']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/1.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_lines.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/1/1.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_lines_straight.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/1/2.png']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_lines_looped.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/1/2/1.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_lines_looped_loopedwithwhitehalo.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/1/3.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_lines_curved.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/1/4.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_lines_serpentine.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/1/5.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_lines_helical.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/1/6.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_lines_coiled.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/1/7.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_lines_branched.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_dots.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/3.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_clods.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/4.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_milky-redarea.jpg
# /usr/local/bin/convert ./['../static/rev2/5/4/5.png']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/vessels_polymorphousvessels.jpg
# /usr/local/bin/convert ./['../static/rev2/5/5.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/other.jpg
# /usr/local/bin/convert ./['../static/rev2/5/5/1.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/other_shinywhitelines.jpg
# /usr/local/bin/convert ./['../static/rev2/5/5/2.jpg']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/other_circles.jpg
# /usr/local/bin/convert ./['../static/rev2/5/5/3.png']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/other_pseudopods.jpg
# /usr/local/bin/convert ./['../static/rev2/5/5/4.tif']  -gravity center -resize 300x200 -extent 300x200 -background white ./../static/derm/images/other_sharplydemarcatedscallopedborder.jpg

# %%
for s in struct_list:
    print '''{ value : '%s', color: %s, icon: "images/%s.jpg", title: '%s' },''' % (s[1], s[5], s[6], s[3])
# Out:
# { value : '', color: [251, 0, 13], icon: "images/lines-reticular.jpg", title: 'Lines, Reticular' },
# { value : '', color: [236, 252, 1], icon: "images/lines-parallel.jpg", title: 'Lines, Parallel' },
# { value : '', color: [236, 252, 2], icon: "images/lines-parallel_furrow.jpg", title: 'Furrow' },
# { value : '', color: [236, 252, 3], icon: "images/lines-parallel_ridge.jpg", title: 'Ridge' },
# { value : '', color: [236, 252, 4], icon: "images/lines-parallel_fibrillar.jpg", title: 'Fibrillar' },
# { value : '', color: [126, 5, 169], icon: "images/clods.jpg", title: 'Clods' },
# { value : '', color: [126, 6, 169], icon: "images/clods_cobblestoneclods.jpg", title: 'Cobblestone Clods' },
# { value : '', color: [126, 7, 169], icon: "images/clods_regular(round/oval)clods.jpg", title: 'Regular (Round / Oval) Clods' },
# { value : '', color: [20, 209, 8], icon: "images/homogeneous.jpg", title: 'Homogeneous' },
# { value : '10', color: [251, 9, 13], icon: "images/lines.jpg", title: 'Lines' },
# { value : '20', color: [251, 10, 13], icon: "images/lines_reticular.jpg", title: 'Reticular' },
# { value : '21', color: [251, 11, 13], icon: "images/lines_reticular_regular.jpg", title: 'Regular' },
# { value : '22', color: [251, 12, 13], icon: "images/lines_reticular_thick.jpg", title: 'Thick' },
# { value : '23', color: [251, 13, 13], icon: "images/lines_reticular_thin.jpg", title: 'Thin' },
# { value : '24', color: [251, 14, 13], icon: "images/lines_reticular_atypical.jpg", title: 'Atypical' },
# { value : '25', color: [251, 15, 13], icon: "images/lines_reticular_negativenetwork.jpg", title: 'Negative Network' },
# { value : '30', color: [251, 16, 13], icon: "images/lines_radial.jpg", title: 'Radial' },
# { value : '31', color: [251, 17, 13], icon: "images/lines_radial_radiallinesconnectedtoacommonbase.jpg", title: 'Radial lines connected to a common base' },
# { value : '32', color: [251, 18, 13], icon: "images/lines_radial_radiallinesconvergingtoacentraldot.jpg", title: 'Radial lines converging to a central dot' },
# { value : '33', color: [251, 19, 13], icon: "images/lines_radial_radiallines-peripheral.jpg", title: 'Radial lines, peripheral' },
# { value : '40', color: [251, 20, 13], icon: "images/lines_branched.jpg", title: 'Branched' },
# { value : '50', color: [251, 21, 13], icon: "images/lines_parallelandstraight.jpg", title: 'Parallel and straight' },
# { value : '51', color: [251, 22, 13], icon: "images/lines_parallelandstraight_furrows.jpg", title: 'Furrows' },
# { value : '52', color: [251, 23, 13], icon: "images/lines_parallelandstraight_ridges.jpg", title: 'Ridges' },
# { value : '53', color: [251, 24, 13], icon: "images/lines_parallelandstraight_fibrallar.jpg", title: 'Fibrallar' },
# { value : '60', color: [251, 25, 13], icon: "images/lines_curved.jpg", title: 'Curved' },
# { value : '61', color: [251, 26, 13], icon: "images/lines_curved_thick.jpg", title: 'Thick' },
# { value : '62', color: [251, 27, 13], icon: "images/lines_curved_thin.jpg", title: 'Thin' },
# { value : '41', color: [251, 28, 13], icon: "images/lines_zigzag.jpg", title: 'Zig Zag' },
# { value : '70', color: [236, 252, 29], icon: "images/dots-clods.jpg", title: 'Dots & Clods' },
# { value : '71', color: [236, 252, 30], icon: "images/dots-clods_dots.jpg", title: 'Dots' },
# { value : '72', color: [236, 252, 31], icon: "images/dots-clods_dots_atypicaldots.jpg", title: 'Atypical Dots' },
# { value : '73', color: [236, 252, 32], icon: "images/dots-clods_dots_dots-foursquare.jpg", title: 'Dots, Four square' },
# { value : '74', color: [236, 252, 33], icon: "images/dots-clods_dots_dots-circle.jpg", title: 'Dots, Circle' },
# { value : '75', color: [236, 252, 34], icon: "images/dots-clods_dots_dots-lines.jpg", title: 'Dots, Lines' },
# { value : '76', color: [236, 252, 35], icon: "images/dots-clods_clods.jpg", title: 'Clods' },
# { value : '77', color: [236, 252, 36], icon: "images/dots-clods_clods_atypicalclods.jpg", title: 'Atypical Clods' },
# { value : '80', color: [126, 37, 169], icon: "images/structureless.jpg", title: 'Structureless' },
# { value : '81', color: [126, 38, 169], icon: "images/structureless_blue-whiteveil.jpg", title: 'Blue-White Veil' },
# { value : '82', color: [126, 39, 169], icon: "images/structureless_pseudonetwork.jpg", title: 'Pseudonetwork' },
# { value : '83', color: [126, 40, 169], icon: "images/structureless_peripheralbrownstructurelessarea.jpg", title: 'Peripheral brown structureless area' },
# { value : '84', color: [126, 41, 169], icon: "images/structureless_off-centeredblotch.jpg", title: 'Off-centered blotch' },
# { value : '100', color: [20, 209, 42], icon: "images/vessels.jpg", title: 'Vessels' },
# { value : '110', color: [20, 209, 43], icon: "images/vessels_lines.jpg", title: 'Lines' },
# { value : '111', color: [20, 209, 44], icon: "images/vessels_lines_straight.jpg", title: 'Straight' },
# { value : '112', color: [20, 209, 45], icon: "images/vessels_lines_looped.jpg", title: 'Looped' },
# { value : '113', color: [20, 209, 46], icon: "images/vessels_lines_looped_loopedwithwhitehalo.jpg", title: 'Looped with white Halo' },
# { value : '114', color: [20, 209, 47], icon: "images/vessels_lines_curved.jpg", title: 'Curved' },
# { value : '115', color: [20, 209, 48], icon: "images/vessels_lines_serpentine.jpg", title: 'Serpentine' },
# { value : '116', color: [20, 209, 49], icon: "images/vessels_lines_helical.jpg", title: 'Helical' },
# { value : '117', color: [20, 209, 50], icon: "images/vessels_lines_coiled.jpg", title: 'Coiled' },
# { value : '118', color: [20, 209, 51], icon: "images/vessels_lines_branched.jpg", title: 'Branched' },
# { value : '101', color: [20, 209, 52], icon: "images/vessels_dots.jpg", title: 'Dots' },
# { value : '102', color: [20, 209, 53], icon: "images/vessels_clods.jpg", title: 'Clods' },
# { value : '120', color: [20, 209, 54], icon: "images/vessels_milky-redarea.jpg", title: 'Milky-red area' },
# { value : '130', color: [20, 209, 55], icon: "images/vessels_polymorphousvessels.jpg", title: 'Polymorphous vessels' },
# { value : '140', color: [56, 140, 255], icon: "images/other.jpg", title: 'Other' },
# { value : '150', color: [57, 140, 255], icon: "images/other_shinywhitelines.jpg", title: 'Shiny white lines' },
# { value : '151', color: [58, 140, 255], icon: "images/other_circles.jpg", title: 'Circles' },
# { value : '152', color: [59, 140, 255], icon: "images/other_pseudopods.jpg", title: 'Pseudopods' },
# { value : '153', color: [60, 140, 255], icon: "images/other_sharplydemarcatedscallopedborder.jpg", title: 'Sharply demarcated scalloped border' },

# %%
import json

json.dump(dtree, open(decision_tree_out, 'w'), indent=2)
